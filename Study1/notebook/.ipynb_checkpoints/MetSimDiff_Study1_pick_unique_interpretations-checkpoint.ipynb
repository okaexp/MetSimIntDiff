# %% [markdown]
# ### picking up metaphor/simile unique features

# %% [markdown]
# #### import libraries and data

# %%
import openpyxl
import pandas as pd

# %%
#sheet name lst
TITLE_LST = ["1_皮肉は短刀だ",
"2_夕日は銅貨だ",
"3_研究は登山だ",
"4_蝶は踊り子だ",
"5_時間は洪水だ",
"6_暴動は嵐だ",
"7_批判はメスだ",
"8_煙草は時限爆弾だ",
"9_真珠は水滴だ",
"10_つららは水晶細工（すいしょうざいく）だ",
"11_雨雲は薄墨だ",
"12_建物は角砂糖だ",
"13_衝撃は電気だ",
"14_学校は工場だ",
"15_子猫は王女だ",
"16_楽譜は暗号だ",
"17_煙突は石碑だ",
"18_空は鏡だ",
"19_子供は天使だ",
"20_柿はちょうちんだ",
"21_デモは雪崩（なだれ）だ",
"22_疑惑（ぎわく）は腫瘍（しゅよう）だ",
"23_教育は階段だ",
"24_微風は吐息だ",
"25_山は王様だ",
"26_仕事は牢獄（ろうごく）だ",
"27_愛は季節だ",
"28_利息は年貢だ",
"29_椿（つばき）はひとだまだ",
"30_審判は天秤だ",
"31_雑巾は亀だ",
"32_不安は濃霧（のうむ）だ",
"33_理論は建物だ",
"34_希望は灯火だ",
"35_運命は通り魔だ",
"36_沈黙は海底だ",
"37_霧（きり）はベールだ",
"38_激怒は噴火だ",
"39_眼は湖だ",
"40_唇（くちびる）は蛭（ひる）だ",
"41_笑顔は花だ",
"42_心臓は時計だ",
"43_麦畑は海だ",
"44_香水は花束だ",
"45_礼儀は檻（おり）だ"]

# %%
#set data directory
dir_metsimdiff_dat = "../result/MetSimDiff_All.xlsx"

# %% [markdown]
# #### pick unique features for one dataframe

# %%
#data sample
tmp_df = pd.read_excel(dir_metsimdiff_dat, sheet_name=TITLE_LST[0])#pick target sheet
tmp_df
# Out:
#      order Feature  S_freq  M_freq  T_freq  V_freq  刺激候補  楠見先生ご提案  直喩候補  隠喩候補  \
# 0        3     切れる       7       3       0       8   NaN      NaN   1.0   NaN
# 1        5      怖い       5       3       3       5   NaN      NaN   1.0   NaN
# 2        7  差す-他動詞       4       3       0       7   NaN      NaN   1.0   NaN
# 3        4     差さる       6       2       0       0   NaN      NaN   1.0   NaN
# 4        1      鋭い      31      23       0      16   NaN      NaN   NaN   NaN
# ..     ...     ...     ...     ...     ...     ...   ...      ...   ...   ...
# 96      96     折れる       0       0       0       1   NaN      NaN   NaN   NaN
# 97      97    嫌らしい       0       0       1       0   NaN      NaN   NaN   NaN
# 98      98    鬱陶しい       0       1       0       0   NaN      NaN   NaN   NaN
# 99      99      尖る       0       0       0       2   NaN      NaN   NaN   NaN
# 100    100    頼り無い       0       1       0       0   NaN      NaN   NaN   NaN
#
#      共通候補   候補  楠見先生ご助言
# ...

# %%
tmp_df.query('S_freq >= 2 or M_freq >= 2')
# Out:
#     order Feature  S_freq  M_freq  T_freq  V_freq  刺激候補  楠見先生ご提案  直喩候補  隠喩候補  \
# 0       3     切れる       7       3       0       8   NaN      NaN   1.0   NaN
# 1       5      怖い       5       3       3       5   NaN      NaN   1.0   NaN
# 2       7  差す-他動詞       4       3       0       7   NaN      NaN   1.0   NaN
# 3       4     差さる       6       2       0       0   NaN      NaN   1.0   NaN
# 4       1      鋭い      31      23       0      16   NaN      NaN   NaN   NaN
# 5       2      痛い      12      11       0       3   NaN      NaN   NaN   NaN
# 6       6     傷付く       5       5       1       0   NaN      NaN   NaN   NaN
# 7      43    突き刺す       0       2       0       0   NaN      NaN   NaN   1.0
# 8      55      危険       0       3       0       2   NaN      NaN   NaN   1.0
# 9      65     きつい       0       3       1       0   NaN      NaN   NaN   1.0
# 10     66      固い       0       2       0       1   NaN      NaN   NaN   1.0
# ...

# %%
#pick data
def dat2unique_features(input_df):
    """
    以下の手順でFeatureにラベルを付与
    手順1. まずは, S_freqとM_freqのどちらも2未満の回答を除外
    手順2. 以下の条件でClassを付与
     - S_unique: 以下の条件のいずれかかが満たされる時、直喩に固有のfeature
         - S_freqが2以上で、M_freqが0
         - S_freqがM_freqの2倍以上（ただし、M_freqは1ではない）
     - M_unique: 以下の条件のいずれかかが満たされる時、隠喩に固有のfeature
         - M_freqが2以上で、S_freqが0
         - M_freqがS_freqの2倍以上（ただし、M_freqは1ではない）
     - Other: 上記のどちらにもあてはまらないもの
    """
    #不要列の削除
    input_df = input_df[["order", "Feature", "S_freq", "M_freq", "候補"]]
    
    #手順1に当てはまるデータの抽出
    step_one_dat = input_df.query('S_freq >= 2 or M_freq >= 2')

    #手順2のラベルを付与
    step_one_dat["Class"] = ""
    step_two_dat = step_one_dat.reset_index()

    #S_uniqueの付与
    for col, row in step_two_dat.iterrows():
        #S_uniqueの付与
        if (row["S_freq"] > 2 and row["M_freq"] == 0) or (row["S_freq"] >= row["M_freq"]*2 and row["M_freq"] != 1):
            step_two_dat.loc[col, "Class"] = "S_unique"
        #M_uniqueの付与
        elif (row["M_freq"] > 2 and row["S_freq"] == 0) or (row["M_freq"] >= row["S_freq"]*2 and row["S_freq"] != 1):
            step_two_dat.loc[col, "Class"] = "M_unique"
        #Otherの付与
        else:
            step_two_dat.loc[col, "Class"] = "Other"

    return step_two_dat

# %%
def unique_features2type_token_counts(unique_features_df, metaphor):
    """
    unique_featuresからtypeとtokensごとのカウントを求める
    """
    #データの初期化
    S_unique_type_count = 0
    S_unique_token_count = 0
    M_unique_type_count = 0
    M_unique_token_count = 0
    O_unique_type_count = 0
    O_unique_token_count = 0

    #数え上げ
    for col, row in unique_features_df.iterrows():
        if row["Class"] == "S_unique":
            S_unique_type_count += 1
            S_unique_token_count += row["S_freq"]
        elif row["Class"] == "M_unique":
            M_unique_type_count += 1
            M_unique_token_count += row["M_freq"]
        else:
            O_unique_type_count += 1
            O_unique_token_count += row["M_freq"]

    #データフレームに統合
    type_token_counts = pd.DataFrame([[metaphor, S_unique_type_count, S_unique_token_count, M_unique_type_count, M_unique_token_count, O_unique_type_count, O_unique_token_count]],
                                     columns=["metaphor", "S_unique_type_count", "S_unique_token_count", "M_unique_type_count", "M_unique_token_count", "O_unique_type_count", "O_unique_token_count"])

    return type_token_counts

# %%
tmp_df = pd.read_excel(dir_metsimdiff_dat, sheet_name="2_夕日は銅貨だ")
tmp_unique_features_df = dat2unique_features(tmp_df)
tmp_unique_features_df
# Out:
# /var/folders/hk/52x26vr91258smgppkjhl_3w0000gn/T/ipykernel_4727/2535207488.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   step_one_dat["Class"] = ""
#     index  order Feature  S_freq  M_freq   候補     Class
# 0       0      4     温かい       5       1   直喩     Other
# 1       1      8     眩しい       4       2   直喩  S_unique
# 2       2      9      鈍い       3       0   直喩  S_unique
# 3       3     13    輝かしい       2       0   直喩  S_unique
# 4       4      1      赤い      16      11   共通     Other
# 5       5      2      丸い      14      12   共通     Other
# 6       6      3      輝く       6       8   共通     Other
# 7       7      7      奇麗       4      15   隠喩  M_unique
# 8       8     30      固い       1       3   隠喩     Other
# ...

# %%
len(tmp_unique_features_df)
# Out:
# 22

# %%
#count variation of Class
tmp_type_token_counts = unique_features2type_token_counts(tmp_unique_features_df, title)
tmp_type_token_counts
# Out:
#    metaphor  S_unique_type_count  S_unique_token_count  M_unique_type_count  \
# 0  1_皮肉は短刀だ                    2                    13                    7
#
#    M_unique_token_count  O_unique_type_count  O_unique_token_count
# 0                    16                   13                    67

# %% [markdown]
# #### pick unique features for all dataframe
# - ここまで。戻ったら、「dat2unique_featuresで各ラベルを付与したエクセルを保存する」と「unique_features2type_token_countsを結合したデータフレームを作る」をやる

# %%
#dat2unique_featuresで各ラベルを付与したエクセルを保存する
OUTPUT_EXCEL_DIR = "../result/MetSimDiff_All_with_class.xlsx"
book = openpyxl.Workbook()

for title in TITLE_LST:
    #現在のtitleのデータを読み込み
    cur_title_df = pd.read_excel(dir_metsimdiff_dat, sheet_name=title)#pick target sheet
    cur_unique_features_df = dat2unique_features(cur_title_df)

    #データをExcelに保存する
    active_sheet = book.create_sheet(title)
    active_sheet.title = title

    #1行目（見出し）の編集
    active_sheet.cell(column=1, row=1, value="index")
    active_sheet.cell(column=2, row=1, value="order")
    active_sheet.cell(column=3, row=1, value="Feature")
    active_sheet.cell(column=4, row=1, value="S_freq")
    active_sheet.cell(column=5, row=1, value="M_freq")
    active_sheet.cell(column=6, row=1, value="候補")
    active_sheet.cell(column=7, row=1, value="Class")

    #特徴と頻度の書き出し
    for row in range(len(cur_unique_features_df)):#行
        for column in range(7):#列
            active_sheet.cell(column=column+1, row=row+2, value=cur_unique_features_df.iloc[row, column])#値の書き込み

book.save(OUTPUT_EXCEL_DIR)
# Out:
# /var/folders/hk/52x26vr91258smgppkjhl_3w0000gn/T/ipykernel_3883/2535207488.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   step_one_dat["Class"] = ""
# /var/folders/hk/52x26vr91258smgppkjhl_3w0000gn/T/ipykernel_3883/2535207488.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   step_one_dat["Class"] = ""
# /var/folders/hk/52x26vr91258smgppkjhl_3w0000gn/T/ipykernel_3883/2535207488.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#unique_features2type_token_countsを結合したデータフレームを作る
type_token_counts_df = pd.DataFrame(columns=["metaphor", "S_unique_type_count", "S_unique_token_count", "M_unique_type_count", "M_unique_token_count", "O_unique_type_count", "O_unique_token_count"])

for title in TITLE_LST:    
    #現在のtitleのデータを読み込み
    cur_title_df = pd.read_excel(dir_metsimdiff_dat, sheet_name=title)#pick target sheet
    cur_unique_features_df = dat2unique_features(cur_title_df)

    #countデータの作成
    tmp_df = unique_features2type_token_counts(cur_unique_features_df, title)

    #データフレームの結合
    type_token_counts_df = pd.concat([type_token_counts_df, tmp_df])

type_token_counts_ri = type_token_counts_df.reset_index()
type_token_counts_ri
# Out:
# /var/folders/hk/52x26vr91258smgppkjhl_3w0000gn/T/ipykernel_4727/2535207488.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   step_one_dat["Class"] = ""
# /var/folders/hk/52x26vr91258smgppkjhl_3w0000gn/T/ipykernel_4727/2535207488.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   step_one_dat["Class"] = ""
# /var/folders/hk/52x26vr91258smgppkjhl_3w0000gn/T/ipykernel_4727/2535207488.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
type_token_counts_ri.to_excel("../result/MetSimDiff_type_token_counts.xlsx")

# %%
tmp_df
# Out:
#        metaphor  S_unique_type_count  S_unique_token_count  \
# 0  45_礼儀は檻（おり）だ                    1                     2
#
#    M_unique_type_count  M_unique_token_count  O_unique_type_count  \
# 0                    3                     9                   11
#
#    O_unique_token_count
# 0                    56

# %% [markdown]
# ### 以下の3つの特徴を切り出す
# 1. 標的喩辞(TargetVehicle)・競合喩辞(CompetitiveVehicle)の共有特徴
# 1. 標的喩辞・競合喩辞の共有特徴・示唆特徴

# %% [markdown]
# #### 共有特徴と示唆特徴を取る関数

# %%
def pick_shared_features(db, db_keys_lst):
    """
    db中のkeyの積集合を取る関数
    db:
        feature_db
    db_keys_lst:
        ・入力する文字列を読み込む
    """
    return_lst = list()

    for i in range(1, 46):
        for k, cur_word in enumerate(db_keys_lst):
            cur_key = cur_word + str(i).zfill(2)#T→T01にする
            if k == 0:#積集合を取るための初期化
                ret_set = set(db[cur_key])
            ret_set &= set(db[cur_key])#積集合を作る：T01 & V01
        return_lst.append(ret_set)#結果をリストに保存する

    return return_lst

def pick_distinctive_features(db, db_keys_lst):
    """
    db中のkeyの差集合を取る関数
    db:
        feature_db
    db_keys_lst:
        ・入力する文字列を読み込む
    """
    return_lst = list()

    for i in range(1, 46):
        for k, cur_word in enumerate(db_keys_lst):#T→T01にする
            cur_key = cur_word + str(i).zfill(2)
            if k == 0:#差集合を取るための初期化
                ret_set = set(db[cur_key])
            else:
                ret_set = ret_set - set(db[cur_key])#差集合を作る：T01 - V01
        return_lst.append(ret_set)#結果をリストに保存する
        
    return return_lst

# %%
#1. 標的喩辞(TargetVehicle, TV)・競合喩辞(CompetitiveVehicle, TC)の共有特徴
#2. 標的喩辞(TV)・競合喩辞(TC)の示唆特徴
MTV_shared = pick_shared_features(db=feature_db, db_keys_lst=["TV", "T", "V"])
TV_shared = pick_shared_features(db=feature_db, db_keys_lst=["T", "V"])
M_distinct = pick_distinctive_features(feature_db, ["TV", "T", "V"])
T_distinct = pick_distinctive_features(feature_db, ["T", "TV", "V"])
V_distinct = pick_distinctive_features(feature_db, ["V", "TV", "T"])
#TC_TV_distinct = pick_distinctive_features(feature_db, ["TC", "TV"])

# %%
print(MTV_shared[0])

# %%
print(TV_shared[0])

# %%
print(M_distinct[0])

# %%
print(T_distinct[0])

# %%
print(V_distinct[0])

# %% [markdown]
# ### 形態素の絞り込みをかける
# - 共有特徴について：対応する3つの単語(主題、標的喩辞、競合喩辞)について、もっともその出現頻度が低い単語の数を求める
#     - 共有アイテムを回す
#     - キーを回す
#     - そのキーを作る
#     - そのアイテムのそのキーの値（頻度）を保存する
#     - そのアイテムのキーの最低値を保存する
#     - アイテムのキーの最低値のなかで、最大の値の、単語と値を保存する
# - 示唆特徴について：頻度の多い順に降順で3つ求めて様子を見る

# %% [markdown]
# 共有特徴について：対応する3つの単語(主題、標的喩辞、競合喩辞)について、もっともその出現頻度が低い単語の数を求める

# %%
from operator import itemgetter

keys = ["T", "V", "TV"]
#keys = ["TV", "TC"]

cur_freqs = list()
cur_min_lst = list()
min_lst = list()

cur_best_freq = 0
cur_best_dict = dict()#cur_best_dict["01"] = ("")

for i, elem_set in enumerate(MTV_shared, 1):
    for elem in elem_set:#温かい
        for key in keys:
            cur_key = key + str(i).zfill(2)#T01
            #print(elem, cur_key, feature_db[cur_key][elem])#温かい T01 5
            #print(cur_key, feature_db[cur_key][elem])
            cur_freqs.append(feature_db[cur_key][elem])
        #print(cur_freqs)#[5, 1, 12]
        cur_min_lst.append((elem, keys[cur_freqs.index(min(cur_freqs))], min(cur_freqs)))
        #print(cur_min_lst)#[('温かい', 'V', 1)]
        cur_freqs = list()#初期化
    cur_min_lst = max(cur_min_lst, key=itemgetter(2))#タプルの2番目の要素がもっとも大きいタプルを持ってくる
    min_lst.append(cur_min_lst)#cur_min_lst: ('明るい', 'V', 3)
    cur_min_lst = list()#初期化

# %%
min_lst

# %%
#pd.DataFrame(min_lst)

# %%
#データフレームの吐き出し
#min_lst_df = pd.DataFrame(min_lst)
#min_lst_df.to_csv("./t_tv_cv_common.csv")

# %% [markdown]
# 示唆特徴について：頻度の多い順に降順で3つ求めて様子を見る

# %%
def pick_top3_distinctive_features(key, Original_Diff_lst):
    """
    示唆特徴を頻度の多い順にすべて列挙する
    
    Parameters
    ----------
    key: string
        どのキーについて示唆特徴を収集するか
    Original_Diff_lst: list
        示唆特徴をまとめたリスト
    """
    O_D_distinct_freqs = list()
    O_D_distinct_top3s = list()
    cur_lst = list()
    
    for i, distinct in enumerate(Original_Diff_lst, 1):
        cur_key = key + str(i).zfill(2)
        for elem in distinct:
            #print(cur_key, elem)
            cur_lst.append((elem, feature_db[cur_key][elem]))
        O_D_distinct_freqs.append(cur_lst)
        cur_lst = list()

    for distinct_lst in O_D_distinct_freqs:
        for rank, most in enumerate(sorted(distinct_lst, key=lambda tup: tup[1], reverse=True), 1):#特徴とその頻度の
            cur_lst.append(most)

            #if rank >= 3:
            #    break

        O_D_distinct_top3s.append(cur_lst)
        cur_lst = list()
        
    return O_D_distinct_top3s

# %%
#示唆特徴を取ってくる
M_distinct_top3 = pick_top3_distinctive_features("TV", M_distinct)
T_distinct_top3 = pick_top3_distinctive_features("T", T_distinct)
V_distinct_top3 = pick_top3_distinctive_features("V", V_distinct)
#TC_TV_distinct_top3 = pick_top3_distinctive_features("TC", TC_TV_distinct)

# %%
M_distinct_top3

# %%
T_distinct_top3

# %%
V_distinct_top3

# %% [markdown]
# #### 色々と吐き出す

# %%
import pandas as pd

# %%
def distinct_top3_to_pd(distinct_lst):
    cur_lst = list()
    fin_lst = list()
    for cur_tuple in distinct_lst:
        for elem in cur_tuple:
            cur_lst.append(elem[0])
            cur_lst.append(elem[1])
        fin_lst.append(cur_lst)
        cur_lst = list()
    
    ret_df = pd.DataFrame(fin_lst)
    
    return ret_df

# %%
distinct_top3_to_pd(M_distinct_top3)

# %%
#色々吐き出す
M_distinct_top3_df = distinct_top3_to_pd(M_distinct_top3)
T_distinct_top3_df = distinct_top3_to_pd(T_distinct_top3)
V_distinct_top3_df = distinct_top3_to_pd(V_distinct_top3)

# %%
#全部保存する
M_distinct_top3_df.to_csv("./M_distinct.csv", encoding="shift_jis", index=False)
T_distinct_top3_df.to_csv("./T_distinct.csv", encoding="shift_jis", index=False)
V_distinct_top3_df.to_csv("./V_distinct.csv", encoding="shift_jis", index=False)

# TV_TC_distinct_top3_df.to_csv("./TV_TC_distinct_rmInvalid_top3.csv", encoding="shift_jis", index=False)
# TC_TV_distinct_top3_df.to_csv("./TC_TV_distinct_rmInvalid_top3.csv", encoding="shift_jis", index=False)

# %% [markdown]
# ### 共有特徴を全部取ってくる

# %%
from operator import itemgetter

keys = ["T", "V"]

cur_freqs = list()
cur_min_lst = list()
min_lst = list()

cur_best_freq = 0
cur_best_dict = dict()#cur_best_dict["01"] = ("")

for i, elem_set in enumerate(TV_shared, 1):
    for elem in elem_set:#温かい
        for key in keys:
            cur_key = key + str(i).zfill(2)#T01
            #print(elem, cur_key, feature_db[cur_key][elem])#温かい T01 5
            cur_freqs.append(feature_db[cur_key][elem])
        #print(cur_freqs)#[5, 1, 12]
        cur_min_lst.append((elem, keys[cur_freqs.index(min(cur_freqs))], min(cur_freqs)))
        #print(cur_min_lst)#[('温かい', 'V', 1)]
        cur_freqs = list()#初期化
    #cur_min_lst = max(cur_min_lst, key=itemgetter(2))#タプルの2番目の要素がもっとも大きいタプルを持ってくる
    min_lst.append(cur_min_lst)#cur_min_lst: ('明るい', 'V', 3)
    cur_min_lst = list()#初期化

# %%
min_lst

# %%
cur_lst = list()
fin_lst = list()
for items in min_lst:
    for elems in sorted(items, key = lambda x:x[2], reverse=True):
        for elem in elems:
            cur_lst.append(elem)
    fin_lst.append(cur_lst)
    cur_lst = list()
    
fin_df = pd.DataFrame(fin_lst)

# %%
fin_df

# %%
fin_df.to_csv("./TV_shared_features.csv", encoding="shift_jis", index=False)
